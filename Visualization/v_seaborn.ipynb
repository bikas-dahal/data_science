# %%
import pandas as pd 
from pathlib import Path
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import ticker
import seaborn as sns

# %% [markdown]
# ### Available styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - tick

# %%
sns.set_style('darkgrid')

# %%
src_file = Path.cwd() / 'vehicles.csv'
img_dir = Path.cwd() / 'images'

# %%
df = pd.read_csv(src_file)
df.tail()
# Out:
# C:\Users\RIPPLE\AppData\Local\Temp\ipykernel_25436\1234316935.py:1: DtypeWarning: Columns (72,74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(src_file)
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 47360  13.523182         0.0        0.0        0.0      19      0.0        0
# 47361  12.935217         0.0        0.0        0.0      20      0.0        0
# 47362  14.167143         0.0        0.0        0.0      18      0.0        0
# 47363  14.167143         0.0        0.0        0.0      18      0.0        0
# 47364  16.528333         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 47360       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 47361       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...

# %%
sns.displot(df, x = 'comb08')

# %%
sns.displot(df, x = 'comb08', kind= 'kde')

# %%
sns.displot(df, x = 'comb08', kind= 'ecdf')

# %%
sns.displot(df, x = 'comb08', kind= 'kde', rug=True)

# %%
sns.histplot(df, x = 'comb08')
# Out:
# <Axes: xlabel='comb08', ylabel='Count'>

# %%
sns.catplot(df, x = 'comb08')

# %%
sns.catplot(df, y = 'comb08', kind='box')

# %%
sns.catplot(df, y = 'comb08', kind='violin')

# %%
sns.catplot(df,x = 'cylinders', y = 'comb08', kind='bar')

# %%
sns.catplot(df,x = 'cylinders', y = 'comb08', kind='point')

# %%
sns.relplot(
    data=df,
    x = 'cylinders',
    y = 'comb08',
)

# %%
sns.relplot(
    data=df,
    x = 'cylinders',
    y = 'comb08',
    
    kind='line',
    hue='city08',
)

# %%
sns.displot(
    data =df,
    x = 'fuelCost08',
    hue = 'year',
    aspect = 2.5
)

# %%
sns.displot(
    data =df,
    x = 'fuelCost08',
    col = 'year',
)

# %%
sns.relplot(
    data=df,
    x = 'cylinders',
    y = 'comb08',
    hue='year',
    kind='line'
)

# %%
sns.catplot(
    data=df,
    x = 'year',
    y = 'comb08',
    kind='boxen',
    showfliers = False
)

# %%
sns.catplot(
    data=df,
    x = 'year',
    y = 'comb08',
    kind='box',
    # col=''
    # col_wrap=3
    showfliers = False
)

# %%
sns.catplot(
    data=df,
    x = 'year',
    y = 'comb08',
    kind='point',
    aspect=2
)

# %%
sns.catplot(
    data=df,
    x = 'year',
    y = 'comb08',
    kind='point',
    aspect=2,
    linestyle =None
)

# %%
sns.catplot(
    data=df,
    x = 'year',
    aspect= 2,
    y = 'comb08',
    kind='bar',
    # hue=
    sharex=False,
    linestyle =None
)

# %%
df['drive']
# Out:
# 0                  Rear-Wheel Drive
# 1                  Rear-Wheel Drive
# 2                 Front-Wheel Drive
# 3                  Rear-Wheel Drive
# 4        4-Wheel or All-Wheel Drive
#                     ...
# 47360             Front-Wheel Drive
# 47361             Front-Wheel Drive
# 47362    4-Wheel or All-Wheel Drive
# 47363    4-Wheel or All-Wheel Drive
# 47364    4-Wheel or All-Wheel Drive
# Name: drive, Length: 47365, dtype: object

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'baseModel',
#        'guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2',
# ...

# %%
sns.catplot(
    data=df,
    x = 'cylinders',
    y = 'comb08',
    row = 'year',
    kind='bar',
    hue = 'fuelType',
    col  = 'drive'
)

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'baseModel',
#        'guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2',
# ...

# %%
# fuel_class = pd.crosstab(
#     df['class_summary'],
#     df['fuel_type_summary'],
#     values=df['comb08'],
#     aggfunc='mean'
# )

# fuel_class
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\break\Django\nlp-env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class_summary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 fuel_class = pd.crosstab(
# ...

# %%
sns.heatmap(fuel_class)

# %%
sns.heatmap(
    fuel_class,
    annot=True,
    fmt='.0f',
    cmap='viridis',
)

# %%
fig, ax = plt.subplots(figsize = (8, 5))

sns.heatmap(fuel_class, annot=True, fmt = '.0f', cmap='icefire')
ax.set_ylabel('gg')
fig.savefig(seaborn_heatmap.svg)

# %%
fig, ax = plt.subplots(figsize = (8, 5))
custom_cmap_2 = sns.light_palette('green', as_cmap=False)
sns.heatmap(fuel_class, annot=True, fmt='.0f', cmap=custom_cmap_2, ax=ax)
ax.set_ylabel("Car Type")

# %%
sns.pairplot(df)

# %%
sns.pairplot(
    df, 
    x_vars= ['comb08', 'displ', 'barrels08'],
    y_vars= ['comb08', 'displ', 'barrels08'],
    hue='year'
)

# %%
sns.pairplot(
    df, 
    x_vars= ['comb08', 'displ', 'barrels08'],
    y_vars= ['comb08', 'displ', 'barrels08'],
    kind='kde',
    hue='year'
)

# %%
sns.jointplot(
    data=df,
    x='barrelsA08',
    y = 'displ',
    kind='reg'
)

# %%
sns.jointplot(
    data=df,
    x='barrelsA08',
    y = 'displ',
    hue='year',
)

# %%
sns.jointplot(
    data=df,
    x='barrelsA08',
    y = 'displ',
    hue='year',
    kind='kde'
)
# Out:
# d:\break\Django\nlp-env\Lib\site-packages\seaborn\axisgrid.py:1883: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(x=self.x, ax=self.ax_marg_x, **kwargs)
