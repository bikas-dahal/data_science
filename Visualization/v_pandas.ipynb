# %%
import pandas as pd 
from pathlib import Path
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import ticker

# %%
src_file = Path.cwd() / 'vehicles.csv'
img_dir = Path.cwd() / 'images'

# %%
df = pd.read_csv(src_file)
df.head()
# Out:
# C:\Users\RIPPLE\AppData\Local\Temp\ipykernel_8604\449906633.py:1: DtypeWarning: Columns (72,74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(src_file)
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  14.167143         0.0        0.0        0.0      19      0.0        0
# 1  27.046364         0.0        0.0        0.0       9      0.0        0
# 2  11.018889         0.0        0.0        0.0      23      0.0        0
# 3  27.046364         0.0        0.0        0.0      10      0.0        0
# 4  15.658421         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...

# %%
df['comb08'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['comb08'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['comb08'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
avg_by_year = df.groupby(['year']).agg(
    {'highway08' : 'mean',
    'city08' : 'mean',
    'comb08' : 'mean'}
)

avg_by_year.head()
# Out:
#       highway08     city08     comb08
# year
# 1984  23.075356  17.982688  19.881874
# 1985  23.042328  17.878307  19.808348
# 1986  22.699174  17.665289  19.550413
# 1987  22.445068  17.310345  19.228549
# 1988  22.702655  17.333628  19.328319

# %%
avg_by_year.plot.box(title = 'Gas Milage')
# Out:
# <Axes: title={'center': 'Gas Milage'}>

# %%
avg_by_year.plot(kind='line', title='Gas Mileage')
# Out:
# <Axes: title={'center': 'Gas Mileage'}, xlabel='year'>

# %%
avg_by_year.plot(kind='line', title='Gas Mileage', figsize=(9, 5),
                 xticks=np.arange(1984, 2026, 5), ylim=(15, 32), rot=45)
# Out:
# <Axes: title={'center': 'Gas Mileage'}, xlabel='year'>

# %%
avg_by_year.plot(kind='barh', rot=45, title='Gas Mileage')
# Out:
# <Axes: title={'center': 'Gas Mileage'}, ylabel='year'>

# %%
avg_by_year.plot(kind='area', title='Gas Mileage')
# Out:
# <Axes: title={'center': 'Gas Mileage'}, xlabel='year'>

# %%
fig, ax = plt.subplots(figsize = (9, 4))
avg_by_year.plot(
    kind = 'area',
    ax= ax,
    stacked=False
)
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:0.0f}'))
ax.set(
    ylabel = 'MPG',
    title = 'Gas Mileage'
)
# Out:
# [Text(0, 0.5, 'MPG'), Text(0.5, 1.0, 'Gas Mileage')]

# %%
df.boxplot(
    column=['highway08', 'city08', 'comb08'],
    by = 'cylinders', figsize= (12, 5), layout=(1, 3),
    showfliers = False
)
# Out:
# array([<Axes: title={'center': 'highway08'}, xlabel='cylinders'>,
#        <Axes: title={'center': 'city08'}, xlabel='cylinders'>,
#        <Axes: title={'center': 'comb08'}, xlabel='cylinders'>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix, andrews_curves, parallel_coordinates, radviz

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  14.167143         0.0        0.0        0.0      19      0.0        0
# 1  27.046364         0.0        0.0        0.0       9      0.0        0
# 2  11.018889         0.0        0.0        0.0      23      0.0        0
# 3  27.046364         0.0        0.0        0.0      10      0.0        0
# 4  15.658421         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
scatter_matrix(df[['highway08', 'city08', 'comb08']], alpha=0.2, figsize=(12, 12))
# Out:
# array([[<Axes: xlabel='highway08', ylabel='highway08'>,
#         <Axes: xlabel='city08', ylabel='highway08'>,
#         <Axes: xlabel='comb08', ylabel='highway08'>],
#        [<Axes: xlabel='highway08', ylabel='city08'>,
#         <Axes: xlabel='city08', ylabel='city08'>,
#         <Axes: xlabel='comb08', ylabel='city08'>],
#        [<Axes: xlabel='highway08', ylabel='comb08'>,
#         <Axes: xlabel='city08', ylabel='comb08'>,
#         <Axes: xlabel='comb08', ylabel='comb08'>]], dtype=object)

# %%
df['VClass'].value_counts()
# Out:
# VClass
# Compact Cars                          6397
# Subcompact Cars                       5695
# Midsize Cars                          5666
# Large Cars                            2620
# Two Seaters                           2426
# Standard Pickup Trucks                2354
# Sport Utility Vehicle - 4WD           2078
# Small Sport Utility Vehicle 4WD       1790
# Small Station Wagons                  1742
# Sport Utility Vehicle - 2WD           1627
# Minicompact Cars                      1595
# Standard Sport Utility Vehicle 4WD    1462
# Standard Pickup Trucks 4WD            1455
# Special Purpose Vehicles              1455
# Standard Pickup Trucks 2WD            1445
# Vans                                  1141
# Small Sport Utility Vehicle 2WD       1008
# Special Purpose Vehicle 2WD            739
# Midsize-Large Station Wagons           656
# Midsize Station Wagons                 594
# Small Pickup Trucks                    538
# Small Pickup Trucks 2WD                510
# ...

# %%
car_class = ['Compact Cars', 'Midsize Cars', 'Subcompact Cars', 'Large Cars']
car_class_df = df[['cylinders', 'fuelCost08', 'co2', 'VClass']].query(
    'VClass == @car_class'
).copy()

# %%
car_class_df.head()
# Out:
#    cylinders  fuelCost08  co2           VClass
# 2        4.0        2050   -1  Subcompact Cars
# 4        4.0        3600   -1     Compact Cars
# 5        4.0        2500   -1     Compact Cars
# 6        4.0        2200   -1     Compact Cars
# 7        4.0        2300   -1     Compact Cars

# %%
scatter_matrix(car_class_df, alpha=0.2, figsize=(12, 12))
# Out:
# array([[<Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='fuelCost08', ylabel='cylinders'>,
#         <Axes: xlabel='co2', ylabel='cylinders'>],
#        [<Axes: xlabel='cylinders', ylabel='fuelCost08'>,
#         <Axes: xlabel='fuelCost08', ylabel='fuelCost08'>,
#         <Axes: xlabel='co2', ylabel='fuelCost08'>],
#        [<Axes: xlabel='cylinders', ylabel='co2'>,
#         <Axes: xlabel='fuelCost08', ylabel='co2'>,
#         <Axes: xlabel='co2', ylabel='co2'>]], dtype=object)

# %%
fig, ax1 = plt.subplots(figsize = (10, 4))
andrews_curves(car_class_df, 'VClass', ax=ax1)
ax1.legend(loc = 'upper left')

# %%
fig, ax1 = plt.subplots(figsize = (10, 4))
parallel_coordinates(car_class_df, 'VClass', ax=ax1)
# Out:
# <Axes: >

# %%
fig, ax1 = plt.subplots(figsize = (10, 4))
radviz(car_class_df, 'VClass', ax=ax1)
# Out:
# <Axes: >

# %%
fig, (ax1, ax2, ax3) = plt.subplots(figsize = (10, 10), nrows=3, ncols=1)
andrews_curves(car_class_df, 'VClass', ax=ax1)
ax1.legend(loc = 'upper left')
parallel_coordinates(car_class_df, 'VClass', ax=ax2)
radviz(car_class_df, 'VClass', ax=ax3)
# Out:
# <Axes: >
