# %%
import pandas as pd 
from pathlib import Path
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import ticker
import seaborn as sns 
import altair as alt

# %%
src_file = Path.cwd() / 'vehicles.csv'
img_dir = Path.cwd() / 'images'

# %%
df = pd.read_csv(src_file)
df.tail()
# Out:
# C:\Users\RIPPLE\AppData\Local\Temp\ipykernel_25964\1234316935.py:1: DtypeWarning: Columns (72,74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(src_file)
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 47360  13.523182         0.0        0.0        0.0      19      0.0        0
# 47361  12.935217         0.0        0.0        0.0      20      0.0        0
# 47362  14.167143         0.0        0.0        0.0      18      0.0        0
# 47363  14.167143         0.0        0.0        0.0      18      0.0        0
# 47364  16.528333         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 47360       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 47361       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...

# %%
alt.data_transformers.names()
# Out:
# ['csv', 'default', 'json', 'vegafusion']

# %%
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
alt.Chart(df).mark_circle().encode(
    x = 'displ',
    y = 'comb08'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    x = 'displ',
    y = 'comb08'
)
# Out:
# alt.Chart(...)

# %%
df_edit = df.head(1000)

# %%
alt.Chart(df_edit).mark_point().encode(
    x = 'displ',
    y = 'comb08',
    color='drive',
    shape='drive'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_bar().encode(
    y = 'count()',
    x = 'comb08',
)
# Out:
# alt.Chart(...)

# %%
df_edit.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'baseModel',
#        'guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2',
# ...

# %%
alt.Chart(df_edit).mark_tick().encode(
    y = 'fuelType',
    x = 'barrels08',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_boxplot().encode(
    y = 'fuelCost08',
    x = 'year',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_boxplot().encode(
    y = 'fuelCost08:Q',
    x = 'year:O',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_bar().encode(
    x = 'mean(fuelCost08)',
    y = 'year:O'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_bar().encode(
    alt.X('comb08', type='quantitative', bin=True),
    alt.Y(aggregate='count', type='quantitative'),
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_bar().encode(
    alt.X('comb08', bin=alt.Bin(extent = [0, 5000], step = 250)),
    alt.Y(aggregate='count', type='quantitative'),
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_point().encode(
    alt.X('displ', type='quantitative'),
    alt.Y('comb08'),
    alt.Color('cylinders', type='ordinal')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_point().encode(
    alt.X('displ', type='quantitative'),
    alt.Y('comb08'),
    alt.Color('cylinders', type='quantitative')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_point().encode(
    alt.X('displ', type='quantitative'),
    alt.Y('comb08'),
    alt.Color('cylinders', type='nominal')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_edit).mark_circle(size=50).encode(
    x = 'displ',
    y = 'comb08',
    tooltip= ['make', 'model', 'year']
).interactive()
# Out:
# alt.Chart(...)

# %%
chart1 = alt.Chart(df_edit).mark_tick().encode(
    y = 'fuelType',
    x = 'barrelsA08'
)

chart2 = alt.Chart(df_edit).mark_bar().encode(
    alt.X('barrels08:Q', bin = True),
    alt.Y('count()')
)

chart1 | chart2
# Out:
# alt.HConcatChart(...)

# %%
chart1 & chart2
# Out:
# alt.VConcatChart(...)

# %%
alt.vconcat(chart1, chart2)
# Out:
# alt.VConcatChart(...)

# %%
alt.Chart(df_edit).mark_circle(size=50).encode(
    x = 'displ',
    y = 'comb08',
    tooltip = ['make', 'model', 'year']
).facet('year:N', columns=2)
# Out:
# alt.FacetChart(...)

# %%
bars = alt.Chart(df_edit).mark_bar().encode(
    x = 'mean(comb08):Q',
    y = 'year:O'
)

bars
# Out:
# alt.Chart(...)

# %%
x = alt.Chart(df_edit).mark_rule(color='red').encode(
    x = 'mean(comb08):Q'
)

bars + x
# Out:
# alt.LayerChart(...)

# %%
text = bars.mark_text(
    align='left',
    dx = 3
).encode(text = alt.Text('mean(comb08):Q', format=',.of'))

(bars + x + text)
# Out:
# alt.LayerChart(...)

# %%
(bars + x + text).properties(width = 700)
# Out:
# alt.LayerChart(...)

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
src_file
# Out:
# WindowsPath('d:/break/Django/data_try/vehicles.csv')

# %%
src_file2 = Path.cwd() / 'employee_data.xlsx'
df = pd.read_excel(src_file2, index_col='Employee ID')
df.head(10)
# Out:
#                       Full Name                Department  \
# Employee ID
# S1001                John Smith           Human Resources
# S1002                  Jane Doe                 Marketing
# S1003           Michael Johnson                   Finance
# S1004               Emily Brown                     Sales
# S1005              David Wilson    Information Technology
# S1006               Lisa Taylor                Operations
# S1007           Daniel Martinez          Customer Service
# S1008            Sarah Anderson  Research and Development
# S1009        Christopher Thomas                Production
# S1010           Kimberly Garcia         Quality Assurance
#
#                                  Designation  Hire Date  Annual Salary (USD)
# Employee ID
# S1001                             HR Manager 2023-05-15                60000
# S1002                   Marketing Specialist 2023-08-20                50000
# ...

# %%
alt.Chart(df).mark_bar().encode(
    alt.Y('Hire Date:T', title='Hire Date'),
    alt.X('count(Full Name)', title='Number of Employee'),
    color='Department'
)
# Out:
# alt.Chart(...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, S1001 to S1040
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Full Name            40 non-null     object
#  1   Department           40 non-null     object
#  2   Designation          40 non-null     object
#  3   Hire Date            40 non-null     datetime64[ns]
#  4   Annual Salary (USD)  40 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.9+ KB

# %%
df[df['Designation']  == 'QA Manager']
# Out:
#                   Full Name         Department Designation  Hire Date  \
# Employee ID
# S1020        Jennifer Davis  Quality Assurance  QA Manager 2023-01-17
#
#              Annual Salary (USD)
# Employee ID
# S1020                      75000
